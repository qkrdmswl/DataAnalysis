# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import os


plt.rc("font", family="Malgun Gothic")

# 마이너스 폰트 깨지는 거
plt.rc("axes", unicode_minus = False)

# %%
# retina 설정해서 글씨 조금 선명하게
# %config inlineBackend.figure_format = "retina"

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
df = pd.read_csv("도로교통공단_시도 시군구별 교통사고 통계_20201214.csv", encoding="cp949")
df.shape
# Out:
# (229, 7)

# %%
df
# Out:
#      시도   시군구  사고건수  사망자수  중상자수  경상자수  부상신고자수
# 0    서울   종로구  1133     6   312  1075     172
# 1    서울    중구  1184     5   365  1083     167
# 2    서울   용산구  1187    10   316  1228      70
# 3    서울   성동구  1091    13   294  1063      82
# 4    서울  동대문구  1565    15   507  1340     141
# ..   ..   ...   ...   ...   ...   ...     ...
# 224  울산    남구  1383     9   491  1299     135
# 225  울산    동구   628     1   211   588      18
# 226  울산    북구   693    13   282   731      97
# 227  울산   울주군   906    27   350   899     124
# 228  세종   세종시   922    15   382   893      26
#
# [229 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도      229 non-null    object
#  1   시군구     229 non-null    object
#  2   사고건수    229 non-null    int64
#  3   사망자수    229 non-null    int64
#  4   중상자수    229 non-null    int64
#  5   경상자수    229 non-null    int64
#  6   부상신고자수  229 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 12.6+ KB

# %%
df.columns
# Out:
# Index(['시도', '시군구', '사고건수', '사망자수', '중상자수', '경상자수', '부상신고자수'], dtype='object')

# %%
df.isnull().sum()
# Out:
# 시도        0
# 시군구       0
# 사고건수      0
# 사망자수      0
# 중상자수      0
# 경상자수      0
# 부상신고자수    0
# dtype: int64

# %%
df['시도'].value_counts()
# Out:
# 경기    31
# 서울    25
# 경북    23
# 전남    22
# 강원    18
# 경남    18
# 부산    16
# 충남    15
# 전북    14
# 충북    11
# 인천    10
# 대구     8
# 대전     5
# 울산     5
# 광주     5
# 제주     2
# 세종     1
# Name: 시도, dtype: int64

# %% [markdown]
# ## 2. 데이터 시각화 및 분석

# %%
sns.countplot(data=df, x="시도")

# %%
plt.figure(figsize=(7,5))
sns.barplot(data=df, x="시도", y="사고건수", ci=None)

# %%
df_seoul = df[df['시도']=='서울']
df_seoul
# Out:
#     시도   시군구  사고건수  사망자수  중상자수  경상자수  부상신고자수
# 0   서울   종로구  1133     6   312  1075     172
# 1   서울    중구  1184     5   365  1083     167
# 2   서울   용산구  1187    10   316  1228      70
# 3   서울   성동구  1091    13   294  1063      82
# 4   서울  동대문구  1565    15   507  1340     141
# 5   서울   성북구  1509     8   447  1444     116
# 6   서울   도봉구   852     4   286   742     135
# 7   서울   은평구  1119     7   369   946     149
# 8   서울  서대문구  1113    14   311  1028     270
# 9   서울   마포구  1494     7   410  1521     192
# 10  서울   강서구  1829    20   470  1834     187
# 11  서울   구로구  1529    13   438  1528     130
# 12  서울  영등포구  2439    11   606  2532     313
# 13  서울   동작구  1406     5   402  1366     253
# 14  서울   관악구  1363    10   376  1264     115
# 15  서울   강남구  3722    14   794  3924     464
# 16  서울   강동구  1414    11   430  1290     190
# 17  서울   송파구  2892    13   736  2823     444
# 18  서울   서초구  2418    14   571  2631     328
# 19  서울   양천구  1506    11   342  1527     216
# ...

# %%
plt.figure(figsize=(15,15))
sns.pointplot(data=df_seoul, x="시군구", y="사고건수", ci=None)

# %%
df_geonggi = df[df['시도']=='경기']
df_geonggi
# Out:
#     시도   시군구  사고건수  사망자수  중상자수  경상자수  부상신고자수
# 41  경기   수원시  4920    31  1172  5216     656
# 42  경기   성남시  3801    39  1194  3955     596
# 43  경기  의정부시  1704    17   448  1720     294
# 44  경기   안양시  1616    20   494  1711     161
# 45  경기   부천시  3667    23   929  3837     342
# 46  경기   안산시  3965    27  1111  4505     326
# 47  경기   평택시  3527    51   993  4046     691
# 48  경기   광명시  1068     9   285   879     340
# 49  경기   구리시   751     6   194   818      91
# 50  경기   양주시  1118    19   295  1292      98
# 51  경기   여주시   592    17   206   709      68
# 52  경기   화성시  3008    33   900  3594     288
# 53  경기   시흥시  2480    30   805  2806     269
# 54  경기   파주시  1658    21   506  1719     183
# 55  경기   고양시  3916    39  1096  4126     572
# 56  경기   광주시  1867    20   480  2182     209
# 57  경기   연천군   196    11    91   197      20
# 58  경기   포천시   887    15   327   962     186
# 59  경기   가평군   396     8   150   494      34
# 60  경기   양평군   591    13   223   625     107
# ...

# %%
plt.figure(figsize=(15,15))
sns.pointplot(data=df_geonggi, x="시군구", y="사고건수", ci=None)

# %% [markdown]
# ### 경기도 인구
# ### 1위 수원(100만 이상), 2위 고양(100만 이상), 3위 용인(100만 이상)
# ### => 교통사고 건수는 인구에 비례한다
